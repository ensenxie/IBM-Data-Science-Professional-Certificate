# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Anson**
# Data scientist

# %% [markdown]
# *I am interested in data science because this is exciting!*

# %% [markdown]
# ### The code in Cell 5 supposed to excecute "1+1".

# %%
1+1
# Out:
# 2

# %% [markdown]
# [I'm an inline-style link](https://www.google.com)
#
# ---
#
# 1. apple
# 2. pear
# 3. pine apple
#
# ---
#
# > Blockquotes are very handy in email to emulate reply text.
# > This line is part of the same quote
